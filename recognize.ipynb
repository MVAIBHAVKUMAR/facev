# %%
from deepface import DeepFace

# %%
image = 'C:/Users/mvaib/OneDrive - rupee/Desktop/facev/data/img70.jpg'

# %%
models = [
  "VGG-Face", 
  "Facenet", 
  "Facenet512", 
  "OpenFace", 
  "DeepFace", 
  "DeepID", 
  "ArcFace", 
  "Dlib", 
  "SFace",
]

# %%
res = DeepFace.find(img_path=image, db_path='C:/Users/mvaib/OneDrive - rupee/Desktop/facev/db')
res[0]
# Out:
# WARNING: Representations for images in C:/Users/mvaib/OneDrive - rupee/Desktop/facev/db folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  11  representations found in  representations_vgg_face.pkl
# find function lasts  2.8366425037384033  seconds
#                                             identity  source_x  source_y  \
# 0  C:/Users/mvaib/OneDrive - rupee/Desktop/facev/...       230       339
# 1  C:/Users/mvaib/OneDrive - rupee/Desktop/facev/...       230       339
# 2  C:/Users/mvaib/OneDrive - rupee/Desktop/facev/...       230       339
# 3  C:/Users/mvaib/OneDrive - rupee/Desktop/facev/...       230       339
# 4  C:/Users/mvaib/OneDrive - rupee/Desktop/facev/...       230       339
# 5  C:/Users/mvaib/OneDrive - rupee/Desktop/facev/...       230       339
#
#    source_w  source_h  VGG-Face_cosine
# ...

# %%
h = res[0]['identity']
# Out:
# 'C:/Users/mvaib/OneDrive - rupee/Desktop/facev/db\\20BCS4411/Ishan4.jpg'

# %%
ress = DeepFace.represent(img_path=image)
type(ress)
# Out:
# list

# %%
ress[1]
# Out:
# {'embedding': [0.047837525606155396,
#   0.03653639554977417,
#   0.02806810848414898,
#   -0.007899872027337551,
#   0.008266767486929893,
#   0.021076295524835587,
#   0.028148936107754707,
#   0.039270319044589996,
#   0.022352270781993866,
#   0.014506218023598194,
#   0.042618416249752045,
#   0.006889736279845238,
#   0.03939613327383995,
#   0.03728647157549858,
#   0.024225549772381783,
#   0.009309330023825169,
#   0.02442380040884018,
#   0.05510484054684639,
#   0.05529490485787392,
#   0.04716483876109123,
#   0.04676643759012222,
#   0.04373985156416893,
#   0.017636336386203766,
#   0.023261599242687225,
#   0.026810752227902412,
#   0.041712548583745956,
#   0.031681984663009644,
#   0.01916356012225151,
#   0.020659174770116806,
#   0.0318695493042469,
#   0.038792774081230164,
#   0.031563419848680496,
#   -0.008348633535206318,
#   0.03052707016468048,
#   0.034069620072841644,
#   0.01728760078549385,
#   0.05478179454803467,
#   0.010634235106408596,
# ...
